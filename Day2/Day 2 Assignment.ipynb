# %%
string = input("Enter any String: ")
for x in string:
    print(x, "Ocurred", string.count(x), "times" )
# Out:
# Enter any String: letter
# l Ocurred 1 times
# e Ocurred 2 times
# t Ocurred 2 times
# t Ocurred 2 times
# e Ocurred 2 times
# r Ocurred 1 times
